# %%
#importing necessary libraries 
import pandas as pd
import numpy as np
# import utils

# %%
df = pd.read_csv(r"X:\PROGRAMS\NLP PROJECT\datasets\dataset\cleaned_data.csv")

# %%
df
# Out:
#                                           english_gloss               intent  \
# 0                      garbage not collected for 3 days            complaint
# 1     what is the status of my ration card application?         status_query
# 2                how to apply for new water connection?  information_request
# 3                           street light is not working            complaint
# 4                           drain is completely blocked            complaint
# ...                                                 ...                  ...
# 1255                      water supply irregular timing            complaint
# 1256                         drain overflow during rain            complaint
# 1257                                  low voltage issue            complaint
# 1258                        emergency delay in hospital            complaint
# 1259                       application pending too long         status_query
#
# ...

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split

# %%
x = df["english_gloss"].str.lower()
y = df["intent"]

# %%
x_train, x_test, y_train, y_test = train_test_split( x, y, test_size = 0.2, random_state = 42)

# %%
tfidf_english_gloss = TfidfVectorizer()

# %%
x_train = tfidf_english_gloss.fit_transform(x_train)

# %%
x_test = tfidf_english_gloss.transform(x_test)

# %%
x_train = x_train.toarray()
x_test = x_test.toarray()

# %%
#y_transformation 
from sklearn.preprocessing import LabelEncoder

ohe_intent = LabelEncoder()

# %%
y_train = ohe_intent.fit_transform(y_train.to_numpy().reshape(-1,1))
# Out:
# c:\Users\ajant\anaconda3\envs\myenv\Lib\site-packages\sklearn\preprocessing\_label.py:120: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
y_test = ohe_intent.transform(y_test.to_numpy().reshape(-1,1))
# Out:
# c:\Users\ajant\anaconda3\envs\myenv\Lib\site-packages\sklearn\preprocessing\_label.py:139: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True)

# %%
# y_train = y_train.argmax(axis=1)
# y_test = y_test.argmax(axis=1)

# %%
from sklearn.naive_bayes import GaussianNB

# %%
model_intent = GaussianNB()

# %%
model_intent.fit(x_train, y_train)
# Out:
# GaussianNB()

# %%
y_pred = model_intent.predict(x_test)

# %%
from sklearn.metrics import accuracy_score, classification_report

# %%
print("Validation Accuracy:", accuracy_score(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# Validation Accuracy: 0.8849206349206349
#               precision    recall  f1-score   support
#
#            0       1.00      0.79      0.88        14
#            1       0.99      0.89      0.94       161
#            2       1.00      1.00      1.00         2
#            3       0.69      1.00      0.82         9
#            4       0.69      0.88      0.77        41
#            5       0.71      0.62      0.67         8
#            6       0.74      1.00      0.85        17
#
#     accuracy                           0.88       252
#    macro avg       0.83      0.88      0.85       252
# weighted avg       0.91      0.88      0.89       252

# %%
import pickle

# %%
pickle.dump(model_intent, open(r"X:\PROGRAMS\NLP PROJECT\MODELS\model_intent.pkl", "wb"))
# pickle.dump(tfidf_english_gloss, open(r"X:\PROGRAMS\NLP PROJECT\MODELS\tfidf_english_gloss.pkl", "wb"))
# pickle.dump(ohe_intent, open(r"X:\PROGRAMS\NLP PROJECT\MODELS\ohe_intent.pkl", "wb"))

# %%
ohe_intent.classes_
# Out:
# array(['application_help', 'complaint', 'document_help', 'escalation',
#        'follow_up', 'information_request', 'status_query'], dtype=object)

# %% [markdown]
# from sklearn.naive_bayes import GaussianNB
# model_intent = GaussianNB()
# model_intent.fit(x_train, y_train)
# y_pred = model_intent.predict(x_test)
#
# print("Validation Accuracy:", accuracy_score(y_test, y_pred))
# print(classification_report(y_test, y_pred))

# %%
df
# Out:
#                                           english_gloss               intent  \
# 0                      garbage not collected for 3 days            complaint
# 1     what is the status of my ration card application?         status_query
# 2                how to apply for new water connection?  information_request
# 3                           street light is not working            complaint
# 4                           drain is completely blocked            complaint
# ...                                                 ...                  ...
# 1255                      water supply irregular timing            complaint
# 1256                         drain overflow during rain            complaint
# 1257                                  low voltage issue            complaint
# 1258                        emergency delay in hospital            complaint
# 1259                       application pending too long         status_query
#
# ...

# %%
y_category = df["severity"]

# %%
cat_xtrain, cat_xtest, severity_ytrain, severity_ytest = train_test_split( x, y_category, test_size = 0.2, random_state = 42)

# %%
severity_LE = LabelEncoder()

# %%
severity_ytrain = severity_LE.fit_transform(severity_ytrain)
severity_ytest = severity_LE.transform(severity_ytest)

# %%
from sklearn.naive_bayes import GaussianNB
model_severity = GaussianNB()
model_severity.fit(x_train, severity_ytrain)
y_pred = model_severity.predict(x_test)

print("Validation Accuracy:", accuracy_score(severity_ytest, y_pred))
print(classification_report(severity_ytest, y_pred))
# Out:
# Validation Accuracy: 0.8452380952380952
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         0
#            2       0.00      0.00      0.00         0
#            3       0.00      0.00      0.00         2
#            4       0.00      0.00      0.00         3
#            5       0.75      1.00      0.86        21
#            6       0.91      0.90      0.91        70
#            7       0.93      0.82      0.87        84
#            8       0.89      0.87      0.88        68
#            9       0.09      0.50      0.15         2
#           10       0.00      0.00      0.00         2
#
#     accuracy                           0.85       252
#    macro avg       0.36      0.41      0.37       252
# weighted avg       0.87      0.85      0.85       252
# ...

# %%
severity_LE.classes_
# Out:
# array(['authority_issue', 'health_hazard', 'health_issue', 'health_risk',
#        'information', 'information_query', 'public_hazard',
#        'service_delay', 'service_failure', 'service_issue',
#        'service_request', 'status'], dtype=object)

# %%
pickle.dump(model_severity, open(r"X:\PROGRAMS\NLP PROJECT\MODELS\model_severity.pkl", "wb"))
pickle.dump(severity_LE, open(r"X:\PROGRAMS\NLP PROJECT\MODELS\severity_LE.pkl", "wb"))
